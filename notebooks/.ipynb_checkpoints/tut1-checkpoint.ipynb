# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([1, 2, 3, 4, 5, 6, 7, 8], dtype=float)
y = np.array([1, 2, 3, 4, 5, 6, 7, 8], dtype=float)
noise = np.random.normal(0.4, 0.5, y.shape)
y += noise

# %%
plt.show(X, y)
plt.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 plt.show(X, y)
#
# File /usr/lib/python3.10/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File /usr/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:49, in show(close, block)
#      46 show._to_draw = []
#      47 # only call close('all') if any to close
#      48 # close triggers gc.collect, which can be slow
# ---> 49 if close and Gcf.get_all_fig_managers():
#      50     matplotlib.pyplot.close('all')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
